# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time 
import sqlite3
from datetime import date
import datetime

# %%
#jobnet
l = []

for num in range(5):
        
        url = "https://www.jobnet.co.il/positionresults.aspx?p="+str(num)+"&subprofid=705" # Cyber 705
        r = requests.get(url)
        c = r.content
        soup=BeautifulSoup(c,"html.parser")
        jobs = soup.find_all("div",{'vocab' : 'http://schema.org/'})
        
        for i in range(len(jobs)) :
            m = {}
            date = jobs[i].find_all("a",{"class":"last"})[0].text.split()[-1] # date
            promoted = 'Yes' if jobs[i].find_all("div",{"class":"jobContainerTop GoldJob"}) else 'No'
            if (date != time.strftime("%d/%m/%Y") and promoted == 'No'): break


            
            m['company'] = jobs[i].find_all("span",{"class":"PositionCompanyName"})[0].text# company
            m['title'] =jobs[i].find_all("a",{"class":"title"})[0].text # title
            m['date'] = date # date
            m['desc'] =jobs[i].find_all("i",{"property":"description"})[0].text# desc
            m['skills'] =jobs[i].find_all("i",{"property":"skills"})[0].text# skills
            m['code'] = jobs[i].find_all("div",{"jobContainerDetails"})[0].find_all("i")[1].text# code
            m['promoted'] = promoted
            l.append(m)

print ("scraped")
# Out:
# scraped

# %%
df=pd.DataFrame(l)
df
# Out:
#         code                          company        date  \
# 0   JB-00003          בתי קולנוע תאטראות בע"מ  09/07/2018
# 1       7293                SPL – Software AG  08/07/2018
# 2       7288                SPL – Software AG  08/07/2018
# 3       7229                SPL – Software AG  08/07/2018
# 4    JB-1526                     All Stars-IT  08/07/2018
# 5   JB-00443                    פרימיום ג'ובס  08/07/2018
# 6   JB-00015                Komodo Consulting  08/07/2018
# 7   JB-00016                Komodo Consulting  08/07/2018
# 8   JB-00098                            קומטק  08/07/2018
# 9   JB-02688                           מטריקס  08/07/2018
# 10  JB-00055                           Bugsec  07/07/2018
# 11  JB-00056                     חברה דסקרטית  07/07/2018
# 12  JB-00012                      יזמקו בע''מ  09/07/2018
# 13  JB-05329                   מיינד-יו בע''מ  09/07/2018
# 14  JB-01131  פיקארו השמה גיוס וסורסינג בע"מ   09/07/2018
# 15      6977          PeopleCom Solutions LTD  09/07/2018
# 16      6559                     חברה דסקרטית  09/07/2018
# 17      7428          PeopleCom Solutions LTD  09/07/2018
# 18      7919                         TOP-SOFT  09/07/2018
# 19      7954                         TOP-SOFT  09/07/2018
# 20     11223                   Personal Match  09/07/2018
# 21     89900                   Personal Match  09/07/2018
# 22   1000012                   Personal Match  09/07/2018
# 23  JB-00029                   Personal Match  09/07/2018
# 24  JB-00028                   Personal Match  09/07/2018
# 25      7724                     חברה דסקרטית  09/07/2018
# 26     18117                    Extreme Group  09/07/2018
# 27     17077                    Extreme Group  09/07/2018
# 28     17955                    Extreme Group  09/07/2018
#
#                                                  desc promoted  \
# 0   לחברה בינלאומית, בעלת רשת בתי הקולנוע "יס פלאנ...      Yes
# 1   לחברת Software AG SPL דרוש/ה מיישם/ת הגנת סייב...      Yes
# 2   לחברת Software AG SPL דרוש/ה מיישם/ת סייבר/ אי...      Yes
# 3   ל-Software AG-SPL דרוש/ה איש/אשת אבטחת מידע לא...      Yes
# 4   לאגף אבטחת המידע של חברת טלקום דרוש מומחה הגנת...      Yes
# 5   לחברת הייטק בראשון לציון דרוש/ה איש/ת אחסון וג...      Yes
# 6    Komodo Consulting is looking for top notch H4...      Yes
# 7     Komodo Consulting is looking for top notch H...      Yes
# 8   לארגון ביטחוני גדול באזור המרכז דרוש/ה איש/אשת...      Yes
# 9   איש/ת אבטחת מידע מנוסה בטיפול בתקלות, תחזוקה, ...      Yes
# 10  באגסק מרחיבה את פעילותה ומגייסת איש/ת מכירות ל...      Yes
# 11  באגסק Bugsec חברת ייעוץ משפחתית בתחום אבטחת מי...      Yes
# 12  לחברת אינטגרציה/שירות דרוש/ה איש/ת סיסטם  למחל...       No
# 13  לארגון מוביל בתחום הפארמה הממוקם באזור הרצליה ...       No
# 14  לסטארט אפ ישראלי בתחום ה-Cyber Security בשרונה...       No
# 15  לחברת אבטחת מידע גדולה ומצליחה, דרוש/ה ארכיטקט...       No
# 16  לחברה פיננסית מובילה בלוד דרוש/ה מומחה/ית Storage       No
# 17  לארגון מוביל בתחומו דרוש/ה מומחה/ית מתודולוגיו...       No
# 18  לחברה יציבה ומובילה, דרוש/ה איש/ת תקשורת ואבטח...       No
# 19  לחברת סטארט אפ סופר מעניינת ובצמיחה, דרוש/ה Se...       No
# 20  לחברה בינלאומית דרוש/ה solution architect בתחו...       No
# 21   לחברת מוצר אבטחת מידע במרכז דרוש/ה security r...       No
# 22  לחברה בינלאומית גדולה במרכז דרוש ארכיטקט אבטחת...       No
# 23  חברת הי טק מחפשת security researcher לתפקיד מע...       No
# 24  חברת הי טק מבוססת מחפשת מנהל אבטחת מידע מנוסה ...       No
# 25  לחברת אינטגרציה בתחום ה-CLOUD דרוש/ה אינטגרטור...       No
# 26  לחברת תקשורת מהמובילות בשוק דרוש/ה אינטגרטור/י...       No
# 27  לארגון פיננסי מוביל דרוש/ה איש/ת אבטחת מידע מת...       No
# 28  לארגון מוביל בתחום ה-Fin Tech הממוקם באזור המר...       No
#
#                                                skills  \
# 0   - שנתיים נסיון בעבודה בתחומים המקצועיים:דרישות...
# 1   התפקיד כולל התקנה, ניהול, תפעול ותחזוקה של מוצ...
# 2   ניסיון של 3 שנים לפחות באבטחת מידע.ניסיון בביצ...
# 3   ניסיון מעשי בתחום אבטחת מידע של לפחות 4 שנים- ...
# 4   · ניסיון מעשי של לפחות 5 שנים בתחום אבטחת מידע...
# 5       ניסיון של 3 שנים ומעלה בתחום האחסון - STORAGE
# 6   · A BSc Computer Science or related technical ...
# 7   Requirements:· A BSc Computer Science or relat...
# 8   - בעל/ת תואר אקדמי או בוגר/ת קורסים מקצועיים ר...
# 9   ניסיון של שנתיים ומעלה בטיפול בתקלות, תחזוקה, ...
# 10  " ניסיון של שנתיים ומעלה במכירות /ניהול לקוחות...
# 11  • ניסיון בביצוע סקרי סיכונים.• ידע מקצועי באבט...
# 12  ידע וניסיון בתחום ה-PC – חובה. ידע וניסיון בני...
# 13  ניסיון של חמש שנים לפחות באבטחת מידע חובה. ניס...
# 14  תואר טכנולוגי, 2+ שנות ניסיון במחקר פרוטוקולים...
# 15  · 6+ years of software development experience ...
# 16  לפחות 4 ש"נ ניסיון בתחום ה- STORAGE- חובהניסיו...
# 17  ניסיון של שנתיים לפחות בניהול צוותים טכנולוגיי...
# 18  השכלה רלוונטית בתחום-חובהניסיון של 3 שנים לפחו...
# 19  השכלה רלוונטית לתחום- חובהניסיון של 2 לפחות כא...
# 20  5-7 שנות ניסיון באבטחת מידע.ידע מצויין באנגלית...
# 21  ניסיון מוכח של ביצוע חקירות סייבר , חקירות פור...
# 22  4-7 שנים ניסיון באבטחת מידע.ניסיון בניסוח מסמכ...
# 23  תואר במדעי המחשב/הנדסת תכנה/ממרם/8200ניסיון של...
# 24  בעל תואר במדעים או אחר  - יתרוןבעל CISSP או תע...
# 25  ניסיון במוצרי מיקרוסופט כולל AD/Exchange/Termi...
# 26  ניסיון של 3-5 שנים בתחום חובה הסמכות של יצרנים...
# 27  דרישות המשרה:* הכרות עם עולם הHacking: Web App...
# 28  ידע וניסיון בעבודה עם מוצרי אבטחת מידע של החבר...
#
#                                             title
# 0                        IT  - סיסטם אדמיניסטרטור
# 1                  מיישם/ת הגנת סייבר (משרה 7293)
# 2   מיישם/ת סייבר/ איש/אשת אבטחת מידע (משרה 7288)
# 3                  איש/אשת אבטחת מידע (משרה 7229)
# 4                 מומחה/ית הגנת סייבר ומבדקי חוסן
# 5     איש/ת אחסון וגיבוי עם ניסיון בתחום  STORAGE
# 6                       Senior Penetration Tester
# 7   Penetration Tester- students/ initial positio
# 8                      איש/אשת תשתיות אבטחת מידע
# 9                                איש/ת אבטחת מידע
# 10        איש/ת מכירות לעולם הסייבר ואבטחת המידע
# 11                                 סוקר/ת סיכונים
# 12               איש/ת סיסטם לתמיכה בלקוחות מחשוב
# 13                     איש/אשת תקשורת ואבטחת מידע
# 14                  Hacker - Protocols Researcher
# 15                       R&D; Security Architect
# 16                               מומחה/ית Storage
# 17                           מומחה/ית אבטחת מידע
# 18                  Network and Security Engineer
# 19                          Security Data Analyst
# 20                    ארכיטקט פתרונות אבטחת מידע
# 21                            security reasercher
# 22                            ארכיטקט אבטחת מידע
# 23                          דרוש חוקר אבטחת מידע
# 24               דרוש מנהל אבטחת מידע לחברה במרכז
# 25                        אינטגרטור בתחום ה-CLOUD
# 26                        אינטגרטור/ית אבטחת מידע
# 27                              בקר\ית אבטחת מידע
# 28                       מומחה תקשורת ואבטחת מידע

# %%
promoted = df[df['promoted']=='Yes']
regular = df[df['promoted']=='No']

# %%
#promoted[promoted['date']==time.strftime("%d/%m/%Y")] # only todays promoted 
promoted # active promoted
# Out:
#         code                  company        date  \
# 0   JB-00003  בתי קולנוע תאטראות בע"מ  09/07/2018
# 1       7293        SPL – Software AG  08/07/2018
# 2       7288        SPL – Software AG  08/07/2018
# 3       7229        SPL – Software AG  08/07/2018
# 4    JB-1526             All Stars-IT  08/07/2018
# 5   JB-00443            פרימיום ג'ובס  08/07/2018
# 6   JB-00015        Komodo Consulting  08/07/2018
# 7   JB-00016        Komodo Consulting  08/07/2018
# 8   JB-00098                    קומטק  08/07/2018
# 9   JB-02688                   מטריקס  08/07/2018
# 10  JB-00055                   Bugsec  07/07/2018
# 11  JB-00056             חברה דסקרטית  07/07/2018
#
#                                                  desc promoted  \
# 0   לחברה בינלאומית, בעלת רשת בתי הקולנוע "יס פלאנ...      Yes
# 1   לחברת Software AG SPL דרוש/ה מיישם/ת הגנת סייב...      Yes
# 2   לחברת Software AG SPL דרוש/ה מיישם/ת סייבר/ אי...      Yes
# 3   ל-Software AG-SPL דרוש/ה איש/אשת אבטחת מידע לא...      Yes
# 4   לאגף אבטחת המידע של חברת טלקום דרוש מומחה הגנת...      Yes
# 5   לחברת הייטק בראשון לציון דרוש/ה איש/ת אחסון וג...      Yes
# 6    Komodo Consulting is looking for top notch H4...      Yes
# 7     Komodo Consulting is looking for top notch H...      Yes
# 8   לארגון ביטחוני גדול באזור המרכז דרוש/ה איש/אשת...      Yes
# 9   איש/ת אבטחת מידע מנוסה בטיפול בתקלות, תחזוקה, ...      Yes
# 10  באגסק מרחיבה את פעילותה ומגייסת איש/ת מכירות ל...      Yes
# 11  באגסק Bugsec חברת ייעוץ משפחתית בתחום אבטחת מי...      Yes
#
#                                                skills  \
# 0   - שנתיים נסיון בעבודה בתחומים המקצועיים:דרישות...
# 1   התפקיד כולל התקנה, ניהול, תפעול ותחזוקה של מוצ...
# 2   ניסיון של 3 שנים לפחות באבטחת מידע.ניסיון בביצ...
# 3   ניסיון מעשי בתחום אבטחת מידע של לפחות 4 שנים- ...
# 4   · ניסיון מעשי של לפחות 5 שנים בתחום אבטחת מידע...
# 5       ניסיון של 3 שנים ומעלה בתחום האחסון - STORAGE
# 6   · A BSc Computer Science or related technical ...
# 7   Requirements:· A BSc Computer Science or relat...
# 8   - בעל/ת תואר אקדמי או בוגר/ת קורסים מקצועיים ר...
# 9   ניסיון של שנתיים ומעלה בטיפול בתקלות, תחזוקה, ...
# 10  " ניסיון של שנתיים ומעלה במכירות /ניהול לקוחות...
# 11  • ניסיון בביצוע סקרי סיכונים.• ידע מקצועי באבט...
#
#                                             title
# 0                        IT  - סיסטם אדמיניסטרטור
# 1                  מיישם/ת הגנת סייבר (משרה 7293)
# 2   מיישם/ת סייבר/ איש/אשת אבטחת מידע (משרה 7288)
# 3                  איש/אשת אבטחת מידע (משרה 7229)
# 4                 מומחה/ית הגנת סייבר ומבדקי חוסן
# 5     איש/ת אחסון וגיבוי עם ניסיון בתחום  STORAGE
# 6                       Senior Penetration Tester
# 7   Penetration Tester- students/ initial positio
# 8                      איש/אשת תשתיות אבטחת מידע
# 9                                איש/ת אבטחת מידע
# 10        איש/ת מכירות לעולם הסייבר ואבטחת המידע
# 11                                 סוקר/ת סיכונים

# %%
regular
# Out:
#         code                          company        date  \
# 12  JB-00012                      יזמקו בע''מ  09/07/2018
# 13  JB-05329                   מיינד-יו בע''מ  09/07/2018
# 14  JB-01131  פיקארו השמה גיוס וסורסינג בע"מ   09/07/2018
# 15      6977          PeopleCom Solutions LTD  09/07/2018
# 16      6559                     חברה דסקרטית  09/07/2018
# 17      7428          PeopleCom Solutions LTD  09/07/2018
# 18      7919                         TOP-SOFT  09/07/2018
# 19      7954                         TOP-SOFT  09/07/2018
# 20     11223                   Personal Match  09/07/2018
# 21     89900                   Personal Match  09/07/2018
# 22   1000012                   Personal Match  09/07/2018
# 23  JB-00029                   Personal Match  09/07/2018
# 24  JB-00028                   Personal Match  09/07/2018
# 25      7724                     חברה דסקרטית  09/07/2018
# 26     18117                    Extreme Group  09/07/2018
# 27     17077                    Extreme Group  09/07/2018
# 28     17955                    Extreme Group  09/07/2018
#
#                                                  desc promoted  \
# 12  לחברת אינטגרציה/שירות דרוש/ה איש/ת סיסטם  למחל...       No
# 13  לארגון מוביל בתחום הפארמה הממוקם באזור הרצליה ...       No
# 14  לסטארט אפ ישראלי בתחום ה-Cyber Security בשרונה...       No
# 15  לחברת אבטחת מידע גדולה ומצליחה, דרוש/ה ארכיטקט...       No
# 16  לחברה פיננסית מובילה בלוד דרוש/ה מומחה/ית Storage       No
# 17  לארגון מוביל בתחומו דרוש/ה מומחה/ית מתודולוגיו...       No
# 18  לחברה יציבה ומובילה, דרוש/ה איש/ת תקשורת ואבטח...       No
# 19  לחברת סטארט אפ סופר מעניינת ובצמיחה, דרוש/ה Se...       No
# 20  לחברה בינלאומית דרוש/ה solution architect בתחו...       No
# 21   לחברת מוצר אבטחת מידע במרכז דרוש/ה security r...       No
# 22  לחברה בינלאומית גדולה במרכז דרוש ארכיטקט אבטחת...       No
# 23  חברת הי טק מחפשת security researcher לתפקיד מע...       No
# 24  חברת הי טק מבוססת מחפשת מנהל אבטחת מידע מנוסה ...       No
# 25  לחברת אינטגרציה בתחום ה-CLOUD דרוש/ה אינטגרטור...       No
# 26  לחברת תקשורת מהמובילות בשוק דרוש/ה אינטגרטור/י...       No
# 27  לארגון פיננסי מוביל דרוש/ה איש/ת אבטחת מידע מת...       No
# 28  לארגון מוביל בתחום ה-Fin Tech הממוקם באזור המר...       No
#
#                                                skills  \
# 12  ידע וניסיון בתחום ה-PC – חובה. ידע וניסיון בני...
# 13  ניסיון של חמש שנים לפחות באבטחת מידע חובה. ניס...
# 14  תואר טכנולוגי, 2+ שנות ניסיון במחקר פרוטוקולים...
# 15  · 6+ years of software development experience ...
# 16  לפחות 4 ש"נ ניסיון בתחום ה- STORAGE- חובהניסיו...
# 17  ניסיון של שנתיים לפחות בניהול צוותים טכנולוגיי...
# 18  השכלה רלוונטית בתחום-חובהניסיון של 3 שנים לפחו...
# 19  השכלה רלוונטית לתחום- חובהניסיון של 2 לפחות כא...
# 20  5-7 שנות ניסיון באבטחת מידע.ידע מצויין באנגלית...
# 21  ניסיון מוכח של ביצוע חקירות סייבר , חקירות פור...
# 22  4-7 שנים ניסיון באבטחת מידע.ניסיון בניסוח מסמכ...
# 23  תואר במדעי המחשב/הנדסת תכנה/ממרם/8200ניסיון של...
# 24  בעל תואר במדעים או אחר  - יתרוןבעל CISSP או תע...
# 25  ניסיון במוצרי מיקרוסופט כולל AD/Exchange/Termi...
# 26  ניסיון של 3-5 שנים בתחום חובה הסמכות של יצרנים...
# 27  דרישות המשרה:* הכרות עם עולם הHacking: Web App...
# 28  ידע וניסיון בעבודה עם מוצרי אבטחת מידע של החבר...
#
#                                title
# 12  איש/ת סיסטם לתמיכה בלקוחות מחשוב
# 13        איש/אשת תקשורת ואבטחת מידע
# 14     Hacker - Protocols Researcher
# 15          R&D; Security Architect
# 16                  מומחה/ית Storage
# 17              מומחה/ית אבטחת מידע
# 18     Network and Security Engineer
# 19             Security Data Analyst
# 20       ארכיטקט פתרונות אבטחת מידע
# 21               security reasercher
# 22               ארכיטקט אבטחת מידע
# 23             דרוש חוקר אבטחת מידע
# 24  דרוש מנהל אבטחת מידע לחברה במרכז
# 25           אינטגרטור בתחום ה-CLOUD
# 26           אינטגרטור/ית אבטחת מידע
# 27                 בקר\ית אבטחת מידע
# 28          מומחה תקשורת ואבטחת מידע

# %%
promoted.to_html('promoted.html')
regular.to_html('regular.html')

# %%
import smtplib
import imghdr
from email.message import EmailMessage
import account

EMAIL = account.mail
SENDTO = account.sendto
PASSWORD = account.password

msg = EmailMessage()
msg['Subject'] = 'Promoted job list'
msg['From'] = EMAIL
msg['To'] = SENDTO
msg.preamble = 'Promoted job list'
file ='promoted.html'


with open(file, 'rb') as f:
    attach = f.read()
msg.add_attachment(attach, maintype='text', subtype='html')

with smtplib.SMTP('smtp.mail.com', 587) as s:
    s.login(EMAIL, PASSWORD)
    s.send_message(msg)
